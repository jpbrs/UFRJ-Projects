# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb
import math

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
sample_sub = pd.read_csv("sampleSubmission.csv")

# %%
f = lambda x: np.sign(x) * np.power(abs(x), 1./3)

# %%
train['cubic_root_x'] = f(train['x'])
train['cubic_root_y'] = f(train['y'])
train['cubic_root_z'] = f(train['z'])
train['cubic_root_table'] = f(train['table'])
train['cubic_root_depth'] = f(train['depth'])
train['cubic_root_carat'] = f(train['carat'])

# %%
train['log_y'] = np.log(train['y']+1)
train['log_x'] = np.log(train['x']+1)
train['log_depth'] = np.log(train['depth'])
train['log_table'] = np.log(train['table'])
train['log_price'] = np.log(train['price'])

# %%
test['log_carat'] = np.log(test['carat'])
test['log_depth'] = np.log(test['depth'])
test['log_table'] = np.log(test['table'])

test['cubic_root_carat'] = f(test['carat'])
test['cubic_root_x'] = f(test['x'])
test['cubic_root_y'] = f(test['y'])
test['cubic_root_z'] = f(test['z'])
test['cubic_root_table'] = f(test['table'])
test['cubic_root_depth'] = f(test['depth'])
test['log_y'] = np.log(test['y']+1)

# %%
train['log_z'] = np.log(train['z']+1)
test['log_z'] = np.log(test['z']+1)

# %% [markdown]
# ### AQUI MUDAMOS O DATASET

# %%
train1h = pd.get_dummies(train)

# %%
test1h = pd.get_dummies(test)

# %%
train1h.head()
# Out:
#       id  carat     x  ...  clarity_VS2  clarity_VVS1  clarity_VVS2
# 0  20000   0.35  4.44  ...            0             0             1
# 1  20001   0.70  5.66  ...            0             0             0
# 2  20002   0.32  4.42  ...            0             1             0
# 3  20003   0.30  4.32  ...            0             0             1
# 4  20004   0.33  4.41  ...            0             0             1
#
# [5 rows x 40 columns]

# %%
predicao = test1h[['cubic_root_table','cubic_root_carat','cubic_root_x','log_y','z','cut_Fair','cut_Good','cut_Ideal','cut_Premium','cut_Very Good','color_D','color_E','color_F','color_G','color_H','color_I','color_J','clarity_I1','clarity_IF','clarity_SI1','clarity_SI2','clarity_VS1','clarity_VS2','clarity_VVS1','clarity_VVS2']]
Data_set = train1h[['cubic_root_table','cubic_root_carat','cubic_root_x','log_y','z','cut_Fair','cut_Good','cut_Ideal','cut_Premium','cut_Very Good','color_D','color_E','color_F','color_G','color_H','color_I','color_J','clarity_I1','clarity_IF','clarity_SI1','clarity_SI2','clarity_VS1','clarity_VS2','clarity_VVS1','clarity_VVS2','log_price']]

# %%
Data_set.head()
# Out:
#    cubic_root_table  cubic_root_carat  ...  clarity_VVS2  log_price
# 0          3.870877          0.704730  ...             1   6.682109
# 1          3.825862          0.887904  ...             0   7.644441
# 2          3.825862          0.683990  ...             0   6.897705
# 3          3.784424          0.669433  ...             1   6.447306
# 4          3.892996          0.691042  ...             1   6.361302
#
# [5 rows x 26 columns]

# %%
X = Data_set.drop(columns=['log_price'])

# %%
Y = Data_set['log_price']

# %% [markdown]
# ### SECAO LIVRE

# %%
from sklearn.model_selection import KFold, cross_validate, cross_val_predict
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor

#3013 0.9905700144108485


cv = KFold(n_splits=10)
SEED = 301
np.random.seed(301)



def teste_modelo(modelo, dadosx, dadosy):
  np.random.seed(301)
  nome = ""
  model = str(modelo)
  for i in range(len(model)):
    if model[i] != "(":
      nome = model[0:i+1]
    else:
      results = cross_validate(modelo, dadosx, dadosy, cv = cv, return_train_score=True)
      print("Resultados para o modelo : {} - {}".format(nome, results['test_score'].mean()))

# %%
#rfr = RandomForestRegressor(random_state=SEED)

# %%
#teste_modelo(rfr, X,Y)

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV , KFold , cross_val_score
from sklearn.metrics import mean_squared_log_error,mean_squared_error, r2_score,mean_absolute_error 

X_train, X_test, y_train, y_test = train_test_split(X,Y)

# %%
# clf_rf = RandomForestRegressor()
# clf_rf.fit(X_train , y_train)
# accuracies = cross_val_score(estimator = clf_rf, X = X_train, y = y_train, cv = 5,verbose = 1)
# y_pred = clf_rf.predict(X_test)
# print('')
# print('###### Random Forest ######')
# print('Score : %.4f' % clf_rf.score(X_test, y_test))
# print(accuracies)

# mse = mean_squared_error(y_test, y_pred)
# mae = mean_absolute_error(y_test, y_pred)
# rmse = mean_squared_error(y_test, y_pred)**0.5
# r2 = r2_score(y_test, y_pred)

# print('')
# print('MSE    : %0.2f ' % mse)
# print('MAE    : %0.2f ' % mae)
# print('RMSE   : %0.2f ' % rmse)
# print('R2     : %0.2f ' % r2)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ###### Random Forest ######
# Score : 0.9904
# [0.98941827 0.99113618 0.98960537 0.99039473 0.98931956]
#
# MSE    : 0.01
# MAE    : 0.07
# RMSE   : 0.10
# R2     : 0.99
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.9s finished

# %%
# no_of_test=[100]

# params_dict={'n_estimators':no_of_test,'n_jobs':[-1],'max_features':["auto",'sqrt','log2']}
# clf_rf=GridSearchCV(estimator=RandomForestRegressor(),param_grid=params_dict)
# clf_rf.fit(X_train,y_train)
# print('Score : %.4f' % clf_rf.score(X_test, y_test))
# pred=clf_rf.predict(X_test)
# r2 = r2_score(y_test, pred)
# print('R2     : %0.2f ' % r2)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# Score : 0.9914
# R2     : 0.99

# %%
# clf_rf.fit(X,Y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                              max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators='warn', n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100], 'n_jobs': [-1]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# predicao.head()
# Out:
#    cubic_root_depth  cubic_root_table  ...  clarity_VVS1  clarity_VVS2
# 0          3.972731          3.870877  ...             0             0
# 1          3.955763          3.870877  ...             0             0
# 2          3.947223          3.802952  ...             0             1
# 3          3.962143          3.825862  ...             0             0
# 4          3.960018          3.870877  ...             0             1
#
# [5 rows x 26 columns]

# %%
# np.exp(clf_rf.predict(predicao))
# Out:
# array([13211.67521141,  5172.23827444,  2359.50858648, ...,
#         1351.79405772,  2086.54361436,   791.78205753])

# %%
# sample_sub = sample_sub.drop(columns=['id'])

# %%
# sample_sub['price']=np.exp(clf_rf.predict(predicao))

# %%
# sample_sub.head()
# Out:
#           price
# 0  13211.675211
# 1   5172.238274
# 2   2359.508586
# 3   4816.160282
# 4   2300.111377

# %%
# train1h.query('x==0 or y==0 or z==0')
# Out:
# Empty DataFrame
# Columns: [id, carat, x, y, z, depth, table, price, cubic_root_x, cubic_root_y, cubic_root_z, cubic_root_table, cubic_root_depth, cubic_root_carat, log_y, log_x, log_depth, log_table, log_price, log_z, cut_Fair, cut_Good, cut_Ideal, cut_Premium, cut_Very Good, color_D, color_E, color_F, color_G, color_H, color_I, color_J, clarity_I1, clarity_IF, clarity_SI1, clarity_SI2, clarity_VS1, clarity_VS2, clarity_VVS1, clarity_VVS2]
# Index: []

# %%
# sample_sub.to_csv('OptimizadoComCUbicRootDepth.csv')

# %%
# train['x'].median(), train['y'].median(), train['z'].median()
# Out:
# (5.7, 5.71, 3.52)

# %% [markdown]
# ### LIMPANDO OS DADOS DO CONJUNTO DE TREINO

# %%
train.query('x==0')
# Out:
#           id  carat      cut color  ... log_depth  log_table  log_price  log_z
# 9734   29734   1.20  Premium     D  ...  4.128746   4.077537   9.660524    0.0
# 30141  50141   1.56    Ideal     G  ...  4.130355   3.988984   9.457200    0.0
# 30804  50804   0.71     Good     F  ...  4.160444   4.094345   7.663877    0.0
#
# [3 rows x 23 columns]

# %%
train.query("carat>1.00 and carat<1.3 and cut=='Premium' and color=='D' and clarity=='VVS1'")
# Out:
#           id  carat      cut color  ... log_depth  log_table  log_price     log_z
# 228    20228   1.01  Premium     D  ...  4.082609   4.077537   9.348362  1.585145
# 3582   23582   1.21  Premium     D  ...  4.096010   4.077537   9.752199  1.640937
# 9734   29734   1.20  Premium     D  ...  4.128746   4.077537   9.660524  0.000000
# 29865  49865   1.11  Premium     D  ...  4.127134   3.988984   9.503383  1.640937
#
# [4 rows x 23 columns]

# %%
train['x'][9734] = 6.72
train['y'][9734] = 6.69
train['z'][9734] = 4.16
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
train.query('y==0')
# Out:
#           id  carat    cut color  ... log_depth  log_table  log_price  log_z
# 30141  50141   1.56  Ideal     G  ...  4.130355   3.988984   9.457200    0.0
# 30804  50804   0.71   Good     F  ...  4.160444   4.094345   7.663877    0.0
#
# [2 rows x 23 columns]

# %%
train.query("carat>1.5 and carat<1.6 and cut=='Ideal' and color=='G' and clarity=='VS2'")
# Out:
#           id  carat    cut color  ... log_depth  log_table  log_price     log_z
# 2579   22579   1.51  Ideal     G  ...  4.128746   4.007333   9.512813  1.717395
# 2737   22737   1.52  Ideal     G  ...  4.119037   4.025352   9.484405  1.715598
# 6241   26241   1.54  Ideal     G  ...  4.107590   4.043051   9.641798  1.710188
# 6650   26650   1.55  Ideal     G  ...  4.120662   4.007333   9.540507  1.722767
# 6857   26857   1.51  Ideal     G  ...  4.109233   4.043051   9.528940  1.708378
# 8308   28308   1.51  Ideal     G  ...  4.130355   4.043051   9.468619  1.713798
# 9307   29307   1.56  Ideal     G  ...  4.131961   3.970292   9.531481  1.729884
# 9665   29665   1.55  Ideal     G  ...  4.120662   4.007333   9.549594  1.722767
# 10464  30464   1.53  Ideal     G  ...  4.139955   4.043051   9.465525  1.728109
# 11237  31237   1.54  Ideal     G  ...  4.114147   4.025352   9.531989  1.715598
# 11453  31453   1.53  Ideal     G  ...  4.120662   4.043051   9.500694  1.710188
# 16461  36461   1.52  Ideal     G  ...  4.128746   4.025352   9.530102  1.717395
# 18586  38586   1.52  Ideal     G  ...  4.112512   4.043051   9.460321  1.710188
# 18865  38865   1.54  Ideal     G  ...  4.127134   4.018183   9.481131  1.720979
# 18922  38922   1.51  Ideal     G  ...  4.128746   3.988984   9.437556  1.713798
# 20588  40588   1.51  Ideal     G  ...  4.125520   4.043051   9.481512  1.711995
# 21017  41017   1.55  Ideal     G  ...  4.120662   4.025352   9.554356  1.722767
# 21485  41485   1.51  Ideal     G  ...  4.130355   4.077537   9.485165  1.713798
# 23255  43255   1.51  Ideal     G  ...  4.128746   4.007333   9.580662  1.715598
# 24601  44601   1.51  Ideal     G  ...  4.127134   4.025352   9.490545  1.713798
# 26683  46683   1.54  Ideal     G  ...  4.119037   4.043051   9.348971  1.717395
# 26736  46736   1.56  Ideal     G  ...  4.115780   4.025352   9.563599  1.720979
# 26763  46763   1.54  Ideal     G  ...  4.097672   4.077537   9.511037  1.706565
# 27595  47595   1.57  Ideal     G  ...  4.138361   4.007333   9.433964  1.736951
# 28083  48083   1.51  Ideal     G  ...  4.091006   4.094345   9.460788  1.699279
# 29941  49941   1.51  Ideal     G  ...  4.139955   4.043051   9.264165  1.719189
# 30141  50141   1.56  Ideal     G  ...  4.130355   3.988984   9.457200  0.000000
# 31337  51337   1.51  Ideal     G  ...  4.107590   3.988984   9.410011  1.708378
# 31770  51770   1.52  Ideal     G  ...  4.139955   3.988984   9.533076  1.724551
# 32415  52415   1.51  Ideal     G  ...  4.091006   4.043051   9.489032  1.701105
#
# [30 rows x 23 columns]

# %%
train['x'][30141] = 7.41
train['y'][30141] = 7.47
train['z'][30141] = 4.66
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
train.query('y==0')
# Out:
#           id  carat   cut color  ... log_depth  log_table  log_price  log_z
# 30804  50804   0.71  Good     F  ...  4.160444   4.094345   7.663877    0.0
#
# [1 rows x 23 columns]

# %%
train.query("carat>0.7 and carat<0.8 and cut=='Good' and color=='F' and clarity=='SI2'")
# Out:
#           id  carat   cut color  ... log_depth  log_table  log_price     log_z
# 973    20973   0.74  Good     F  ...  4.136765   4.174387   7.895436  1.515127
# 3751   23751   0.72  Good     F  ...  4.155753   4.077537   7.383368  1.521699
# 11100  31100   0.79  Good     F  ...  4.163560   4.094345   7.571988  1.551809
# 15265  35265   0.71  Good     F  ...  4.152613   4.094345   7.636270  1.521699
# 17920  37920   0.78  Good     F  ...  4.138361   4.110874   7.801391  1.536867
# 23622  43622   0.74  Good     F  ...  4.082609   4.110874   7.691657  1.506297
# 24143  44143   0.73  Good     F  ...  4.062166   4.127134   7.692113  1.490654
# 26657  46657   0.71  Good     F  ...  4.166665   4.018183   7.732808  1.526056
# 30804  50804   0.71  Good     F  ...  4.160444   4.094345   7.663877  0.000000
#
# [9 rows x 23 columns]

# %%
train['x'][30804] = 5.64
train['y'][30804] = 5.61
train['z'][30804] = 3.60
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
train.query('y==0')
# Out:
# Empty DataFrame
# Columns: [id, carat, cut, color, clarity, x, y, z, depth, table, price, cubic_root_x, cubic_root_y, cubic_root_z, cubic_root_table, cubic_root_depth, cubic_root_carat, log_y, log_x, log_depth, log_table, log_price, log_z]
# Index: []

# %%
train.query('z==0')
# Out:
#           id  carat      cut color  ... log_depth  log_table  log_price  log_z
# 2657   22657   1.10  Premium     G  ...  4.143135   4.077537   8.215006    0.0
# 5589   25589   1.01  Premium     F  ...  4.080922   4.060443   8.252446    0.0
# 12157  32157   1.15    Ideal     G  ...  4.080922   4.025352   8.624073    0.0
# 16833  36833   2.02  Premium     H  ...  4.138361   3.970292   9.809561    0.0
# 19721  39721   2.20  Premium     H  ...  4.114147   4.077537   9.756437    0.0
# 24371  44371   1.01  Premium     H  ...  4.062166   4.077537   8.060540    0.0
# 24708  44708   1.00  Premium     G  ...  4.079231   4.077537   8.052615    0.0
# 29200  49200   2.18  Premium     H  ...  4.084294   4.110874   9.443909    0.0
#
# [8 rows x 23 columns]

# %%
train.query('z==0')
# Out:
#           id  carat      cut color  ... log_depth  log_table  log_price  log_z
# 2657   22657   1.10  Premium     G  ...  4.143135   4.077537   8.215006    0.0
# 5589   25589   1.01  Premium     F  ...  4.080922   4.060443   8.252446    0.0
# 12157  32157   1.15    Ideal     G  ...  4.080922   4.025352   8.624073    0.0
# 16833  36833   2.02  Premium     H  ...  4.138361   3.970292   9.809561    0.0
# 19721  39721   2.20  Premium     H  ...  4.114147   4.077537   9.756437    0.0
# 24371  44371   1.01  Premium     H  ...  4.062166   4.077537   8.060540    0.0
# 24708  44708   1.00  Premium     G  ...  4.079231   4.077537   8.052615    0.0
# 29200  49200   2.18  Premium     H  ...  4.084294   4.110874   9.443909    0.0
#
# [8 rows x 23 columns]

# %%
train['z'][2657] = 4.08
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train.query('z==0')
# Out:
#           id  carat      cut color  ... log_depth  log_table  log_price  log_z
# 5589   25589   1.01  Premium     F  ...  4.080922   4.060443   8.252446    0.0
# 12157  32157   1.15    Ideal     G  ...  4.080922   4.025352   8.624073    0.0
# 16833  36833   2.02  Premium     H  ...  4.138361   3.970292   9.809561    0.0
# 19721  39721   2.20  Premium     H  ...  4.114147   4.077537   9.756437    0.0
# 24371  44371   1.01  Premium     H  ...  4.062166   4.077537   8.060540    0.0
# 24708  44708   1.00  Premium     G  ...  4.079231   4.077537   8.052615    0.0
# 29200  49200   2.18  Premium     H  ...  4.084294   4.110874   9.443909    0.0
#
# [7 rows x 23 columns]

# %%
train['z'][5589] = 3.84
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train.query('z==0')
# Out:
#           id  carat      cut color  ... log_depth  log_table  log_price  log_z
# 12157  32157   1.15    Ideal     G  ...  4.080922   4.025352   8.624073    0.0
# 16833  36833   2.02  Premium     H  ...  4.138361   3.970292   9.809561    0.0
# 19721  39721   2.20  Premium     H  ...  4.114147   4.077537   9.756437    0.0
# 24371  44371   1.01  Premium     H  ...  4.062166   4.077537   8.060540    0.0
# 24708  44708   1.00  Premium     G  ...  4.079231   4.077537   8.052615    0.0
# 29200  49200   2.18  Premium     H  ...  4.084294   4.110874   9.443909    0.0
#
# [6 rows x 23 columns]

# %%
train['z'][12157] = 4.06
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train.query('z==0')
# Out:
#           id  carat      cut color  ... log_depth  log_table  log_price  log_z
# 16833  36833   2.02  Premium     H  ...  4.138361   3.970292   9.809561    0.0
# 19721  39721   2.20  Premium     H  ...  4.114147   4.077537   9.756437    0.0
# 24371  44371   1.01  Premium     H  ...  4.062166   4.077537   8.060540    0.0
# 24708  44708   1.00  Premium     G  ...  4.079231   4.077537   8.052615    0.0
# 29200  49200   2.18  Premium     H  ...  4.084294   4.110874   9.443909    0.0
#
# [5 rows x 23 columns]

# %%
train['z'][16833] = 5.01
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train.query('z==0')
# Out:
#           id  carat      cut color  ... log_depth  log_table  log_price  log_z
# 19721  39721   2.20  Premium     H  ...  4.114147   4.077537   9.756437    0.0
# 24371  44371   1.01  Premium     H  ...  4.062166   4.077537   8.060540    0.0
# 24708  44708   1.00  Premium     G  ...  4.079231   4.077537   8.052615    0.0
# 29200  49200   2.18  Premium     H  ...  4.084294   4.110874   9.443909    0.0
#
# [4 rows x 23 columns]

# %%
train['z'][19721] = 5.14
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train.query('z==0')
# Out:
#           id  carat      cut color  ... log_depth  log_table  log_price  log_z
# 24371  44371   1.01  Premium     H  ...  4.062166   4.077537   8.060540    0.0
# 24708  44708   1.00  Premium     G  ...  4.079231   4.077537   8.052615    0.0
# 29200  49200   2.18  Premium     H  ...  4.084294   4.110874   9.443909    0.0
#
# [3 rows x 23 columns]

# %%
train['z'][24371] = 3.85
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train.query('z==0')
# Out:
#           id  carat      cut color  ... log_depth  log_table  log_price  log_z
# 24708  44708   1.00  Premium     G  ...  4.079231   4.077537   8.052615    0.0
# 29200  49200   2.18  Premium     H  ...  4.084294   4.110874   9.443909    0.0
#
# [2 rows x 23 columns]

# %%
train['z'][24708] = 3.85
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train.query('z==0.0')
# Out:
#           id  carat      cut color  ... log_depth  log_table  log_price  log_z
# 29200  49200   2.18  Premium     H  ...  4.084294   4.110874   9.443909    0.0
#
# [1 rows x 23 columns]

# %%
train['z'][29200] = 5.03
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train.query('z==0.0')
# Out:
# Empty DataFrame
# Columns: [id, carat, cut, color, clarity, x, y, z, depth, table, price, cubic_root_x, cubic_root_y, cubic_root_z, cubic_root_table, cubic_root_depth, cubic_root_carat, log_y, log_x, log_depth, log_table, log_price, log_z]
# Index: []

# %%
train['z'][19721]
# Out:
# 5.14

# %%
train.describe()
# Out:
#                  id         carat  ...     log_price         log_z
# count  33940.000000  33940.000000  ...  33940.000000  33940.000000
# mean   36969.500000      0.796249  ...      7.784127      1.500380
# std     9797.778405      0.472866  ...      1.013619      0.153023
# min    20000.000000      0.200000  ...      5.786897      0.000000
# 25%    28484.750000      0.400000  ...      6.858565      1.363537
# 50%    36969.500000      0.700000  ...      7.781139      1.508512
# 75%    45454.250000      1.040000  ...      8.574329      1.615420
# max    53939.000000      5.010000  ...      9.842835      2.076938
#
# [8 rows x 20 columns]

# %%
train.query('y>15')
# Out:
#          id  carat    cut color  ... log_depth  log_table  log_price     log_z
# 2785  22785   0.51  Ideal     E  ...  4.123903   4.007333   7.637716  1.811562
#
# [1 rows x 23 columns]

# %%
train['y'][2785] = 3.18
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ### LIMPANDO OS DADOS DO CONJUNTO DE TESTE

# %%
test.query('x==0')
# Out:
#           id  carat        cut  ... cubic_root_depth     log_y  log_z
# 1930    1930   0.71       Good  ...         4.002082  0.000000    0.0
# 2577    2577   1.07      Ideal  ...         3.949362  2.030776    0.0
# 4635    4635   1.00  Very Good  ...         3.985363  0.000000    0.0
# 6687    6687   2.25    Premium  ...         3.974842  0.000000    0.0
# 12683  12683   1.14       Fair  ...         3.859721  0.000000    0.0
#
# [5 rows x 21 columns]

# %%
test.query("carat>0.7 and carat<0.75 and cut=='Good' and color=='F' and clarity=='SI2'")
# Out:
#           id  carat   cut  ... cubic_root_depth     log_y     log_z
# 1930    1930   0.71  Good  ...         4.002082  0.000000  0.000000
# 15276  15276   0.73  Good  ...         3.987461  1.909543  1.532557
# 17818  17818   0.71  Good  ...         4.000000  1.885553  1.526056
#
# [3 rows x 21 columns]

# %%
test['x'][1930] = 5.64
test['y'][1930] = 5.61
test['z'][1930] = 3.60
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
test.query("carat>1.05 and carat<01.10 and cut=='Ideal' and color=='F' and clarity=='SI2'")
# Out:
#           id  carat    cut  ... cubic_root_depth     log_y     log_z
# 221      221   1.07  Ideal  ...         3.957892  2.013569  1.621366
# 1325    1325   1.06  Ideal  ...         3.930033  2.029463  1.609438
# 2577    2577   1.07  Ideal  ...         3.949362  2.030776  0.000000
# 6773    6773   1.07  Ideal  ...         3.947223  2.024193  1.619388
# 8534    8534   1.09  Ideal  ...         3.940795  2.037317  1.623341
# 12516  12516   1.07  Ideal  ...         3.947223  2.028148  1.619388
# 12854  12854   1.07  Ideal  ...         3.957892  2.028148  1.621366
# 13879  13879   1.09  Ideal  ...         3.940795  2.028148  1.619388
# 18711  18711   1.07  Ideal  ...         3.945083  2.032088  1.619388
#
# [9 rows x 21 columns]

# %%
test['x'][2577] = 6.60
test['z'][2577] = 4.07
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test.query('x==0')
# Out:
#           id  carat        cut  ... cubic_root_depth log_y  log_z
# 4635    4635   1.00  Very Good  ...         3.985363   0.0    0.0
# 6687    6687   2.25    Premium  ...         3.974842   0.0    0.0
# 12683  12683   1.14       Fair  ...         3.859721   0.0    0.0
#
# [3 rows x 21 columns]

# %%
test.query("carat>0.95 and carat<1.05 and cut=='Very Good' and color=='H' and clarity=='VS2'")
# Out:
#           id  carat        cut  ... cubic_root_depth     log_y     log_z
# 181      181   1.00  Very Good  ...         3.985363  1.976855  1.603420
# 400      400   1.04  Very Good  ...         3.923548  2.026832  1.603420
# 854      854   1.01  Very Good  ...         3.949362  2.000128  1.601406
# 1696    1696   1.01  Very Good  ...         3.940795  2.002830  1.599388
# 2011    2011   1.02  Very Good  ...         3.966385  1.994700  1.607436
# 2205    2205   1.03  Very Good  ...         3.912692  2.017566  1.589235
# 3885    3885   1.01  Very Good  ...         3.985363  1.983756  1.607436
# 4624    4624   1.04  Very Good  ...         3.934345  2.028148  1.607436
# 4635    4635   1.00  Very Good  ...         3.985363  0.000000  0.000000
# 5685    5685   1.01  Very Good  ...         3.936497  1.998774  1.589235
# 5852    5852   1.01  Very Good  ...         3.962143  2.006871  1.605430
# 10372  10372   1.01  Very Good  ...         3.983263  1.982380  1.605430
# 10978  10978   1.00  Very Good  ...         3.976951  1.994700  1.605430
# 11811  11811   1.00  Very Good  ...         3.985363  1.986504  1.611436
# 12333  12333   1.01  Very Good  ...         3.968503  2.006871  1.609438
# 13536  13536   1.01  Very Good  ...         3.930033  2.016235  1.597365
# 14055  14055   1.00  Very Good  ...         3.979057  1.993339  1.613430
# 14093  14093   1.00  Very Good  ...         4.014530  1.986504  1.619388
# 15564  15564   1.02  Very Good  ...         3.914868  2.013569  1.591274
# 16723  16723   1.04  Very Good  ...         3.983263  2.004179  1.623341
# 17116  17116   1.01  Very Good  ...         3.974842  1.998774  1.607436
#
# [21 rows x 21 columns]

# %%
test['x'][4635] = 6.32
test['y'][4635] = 6.35
test['z'][4635] = 4.01
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
test.query('x==0')
# Out:
#           id  carat      cut  ... cubic_root_depth log_y  log_z
# 6687    6687   2.25  Premium  ...         3.974842   0.0    0.0
# 12683  12683   1.14     Fair  ...         3.859721   0.0    0.0
#
# [2 rows x 21 columns]

# %%
test.query("carat>2.23 and carat<2.28 and cut=='Premium' and color=='H' and clarity=='SI2'")
# Out:
#         id  carat      cut  ... cubic_root_depth     log_y     log_z
# 1210  1210   2.26  Premium  ...         3.955763  2.233235  1.819699
# 6687  6687   2.25  Premium  ...         3.974842  0.000000  0.000000
#
# [2 rows x 21 columns]

# %%
test['x'][6687] = 8.43
test['y'][6687] = 8.35
test['z'][6687] = 5.27
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
test.query('x==0')
# Out:
#           id  carat   cut  ... cubic_root_depth log_y  log_z
# 12683  12683   1.14  Fair  ...         3.859721   0.0    0.0
#
# [1 rows x 21 columns]

# %%
test.query("carat>1.12 and carat<1.17 and depth>55.0 and depth<60.0 and table>62.5 and table<70.5")
# Out:
#           id  carat   cut  ... cubic_root_depth     log_y     log_z
# 12683  12683   1.14  Fair  ...         3.859721  0.000000  0.000000
# 14464  14464   1.13  Fair  ...         3.823584  2.071913  1.589235
#
# [2 rows x 21 columns]

# %%
test['x'][12683] = 6.97
test['y'][12683] = 6.84
test['z'][12683] = 3.97
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
test.query('x==0')
# Out:
# Empty DataFrame
# Columns: [id, carat, cut, color, clarity, x, y, z, depth, table, log_carat, log_depth, log_table, cubic_root_carat, cubic_root_x, cubic_root_y, cubic_root_z, cubic_root_table, cubic_root_depth, log_y, log_z]
# Index: []

# %%
test.query('y>15')
# Out:
#         id  carat      cut  ... cubic_root_depth     log_y     log_z
# 1893  1893    2.0  Premium  ...         3.890796  4.092677  2.203869
#
# [1 rows x 21 columns]

# %%
test['y'][1893]= 5.89
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test.query('z==0')
# Out:
#           id  carat      cut  ... cubic_root_depth     log_y  log_z
# 1937    1937   1.50     Good  ...         4.000000  2.084429    0.0
# 3879    3879   1.12  Premium  ...         3.923548  2.037317    0.0
# 9960    9960   2.80     Good  ...         3.995829  2.287471    0.0
# 10220  10220   2.25  Premium  ...         3.942940  2.242835    0.0
#
# [4 rows x 21 columns]

# %%
test['z'][10220] = 5.19
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test.query('z==0')
# Out:
#         id  carat      cut  ... cubic_root_depth     log_y  log_z
# 1937  1937   1.50     Good  ...         4.000000  2.084429    0.0
# 3879  3879   1.12  Premium  ...         3.923548  2.037317    0.0
# 9960  9960   2.80     Good  ...         3.995829  2.287471    0.0
#
# [3 rows x 21 columns]

# %%
test['z'][9960] = 5.66
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test.query('z==0')
# Out:
#         id  carat      cut  ... cubic_root_depth     log_y  log_z
# 1937  1937   1.50     Good  ...         4.000000  2.084429    0.0
# 3879  3879   1.12  Premium  ...         3.923548  2.037317    0.0
#
# [2 rows x 21 columns]

# %%
train.query("carat>1.45 and carat<1.55 and x>7 and x<7.3 and y>7 and y<7.1 and color=='G'")
# Out:
#           id  carat   cut color  ... log_depth  log_table  log_price     log_z
# 1908   21908   1.51  Fair     G  ...  4.182050   4.007333   9.081825  1.733424
# 22795  42795   1.50  Good     G  ...  4.152613   4.060443   8.787526  1.711995
# 33037  53037   1.50  Fair     G  ...  4.166665   4.043051   9.244935  1.720979
#
# [3 rows x 23 columns]

# %%
test['z'][1937] = 4.54
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test.query('z==0')
# Out:
#         id  carat      cut  ... cubic_root_depth     log_y  log_z
# 3879  3879   1.12  Premium  ...         3.923548  2.037317    0.0
#
# [1 rows x 21 columns]

# %%
test['z'][3879] = 4.13
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test.query('z==0')
# Out:
# Empty DataFrame
# Columns: [id, carat, cut, color, clarity, x, y, z, depth, table, log_carat, log_depth, log_table, cubic_root_carat, cubic_root_x, cubic_root_y, cubic_root_z, cubic_root_table, cubic_root_depth, log_y, log_z]
# Index: []

# %% [markdown]
# ### AQUI COMEC!AM AS PREDICOES

# %%
train['cubic_root_x'] = f(train['x'])
train['cubic_root_y'] = f(train['y'])
train['cubic_root_z'] = f(train['z'])
train['cubic_root_table'] = f(train['table'])
train['cubic_root_depth'] = f(train['depth'])
train['cubic_root_carat'] = f(train['carat'])
train['log_y'] = np.log(train['y'])
train['log_x'] = np.log(train['x'])
train['log_depth'] = np.log(train['depth'])
train['log_table'] = np.log(train['table'])
train['log_price'] = np.log(train['price'])
test['log_carat'] = np.log(test['carat'])
test['log_depth'] = np.log(test['depth'])
test['log_table'] = np.log(test['table'])

test['cubic_root_carat'] = f(test['carat'])
test['cubic_root_x'] = f(test['x'])
test['cubic_root_y'] = f(test['y'])
test['cubic_root_z'] = f(test['z'])
test['cubic_root_table'] = f(test['table'])
test['cubic_root_depth'] = f(test['depth'])
test['log_y'] = np.log(test['y'])
train['log_z'] = np.log(train['z'])
test['log_z'] = np.log(test['z'])

# %%
train1h = pd.get_dummies(train)
train1h.query("x==0 or y==0 or z==0")
# Out:
# Empty DataFrame
# Columns: [id, carat, x, y, z, depth, table, price, cubic_root_x, cubic_root_y, cubic_root_z, cubic_root_table, cubic_root_depth, cubic_root_carat, log_y, log_x, log_depth, log_table, log_price, log_z, cut_Fair, cut_Good, cut_Ideal, cut_Premium, cut_Very Good, color_D, color_E, color_F, color_G, color_H, color_I, color_J, clarity_I1, clarity_IF, clarity_SI1, clarity_SI2, clarity_VS1, clarity_VS2, clarity_VVS1, clarity_VVS2]
# Index: []

# %%
test1h = pd.get_dummies(test)

# %%
test1h.query("x==0 or y==0 or z==0")
# Out:
# Empty DataFrame
# Columns: [id, carat, x, y, z, depth, table, log_carat, log_depth, log_table, cubic_root_carat, cubic_root_x, cubic_root_y, cubic_root_z, cubic_root_table, cubic_root_depth, log_y, log_z, cut_Fair, cut_Good, cut_Ideal, cut_Premium, cut_Very Good, color_D, color_E, color_F, color_G, color_H, color_I, color_J, clarity_I1, clarity_IF, clarity_SI1, clarity_SI2, clarity_VS1, clarity_VS2, clarity_VVS1, clarity_VVS2]
# Index: []

# %%
predicao = test1h[['cubic_root_table','cubic_root_carat','cubic_root_x','log_y','z','cut_Fair','cut_Good','cut_Ideal','cut_Premium','cut_Very Good','color_D','color_E','color_F','color_G','color_H','color_I','color_J','clarity_I1','clarity_IF','clarity_SI1','clarity_SI2','clarity_VS1','clarity_VS2','clarity_VVS1','clarity_VVS2']]
Data_set = train1h[['cubic_root_table','cubic_root_carat','cubic_root_x','log_y','z','cut_Fair','cut_Good','cut_Ideal','cut_Premium','cut_Very Good','color_D','color_E','color_F','color_G','color_H','color_I','color_J','clarity_I1','clarity_IF','clarity_SI1','clarity_SI2','clarity_VS1','clarity_VS2','clarity_VVS1','clarity_VVS2','log_price']]

# %%
X = Data_set.drop(columns='log_price')

# %%
Y = Data_set[['log_price']]

# %%
from sklearn.model_selection import KFold, cross_validate, cross_val_predict
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor

#3013 0.9905700144108485


cv = KFold(n_splits=10)
SEED = 301
np.random.seed(SEED)



def teste_modelo(modelo, dadosx, dadosy):
  nome = ""
  model = str(modelo)
  for i in range(len(model)):
    if model[i] != "(":
      nome = model[0:i+1]
    else:
      results = cross_validate(modelo, dadosx, dadosy, cv = cv, return_train_score=True)
      print("Resultados para o modelo : {} - {}".format(nome, results['test_score'].mean()))

# %%
rfreg = RandomForestRegressor()
teste_modelo(rfreg,X,Y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-100-72fd5520b7ca> in <module>()
#       1 rfreg = RandomForestRegressor()
# ----> 2 teste_modelo(rfreg,X,Y)
#
# <ipython-input-99-41b641cb3147> in teste_modelo(modelo, dadosx, dadosy)
#      19       nome = model[0:i+1]
#      20     else:
# ---> 21       results = cross_validate(modelo, dadosx, dadosy, cv = cv, return_train_score=True)
#      22       print("Resultados para o modelo : {} - {}".format(nome, results['test_score'].mean()))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     229             return_times=True, return_estimator=return_estimator,
#     230             error_score=error_score)
# --> 231         for train, test in cv.split(X, y, groups))
#     232
#     233     zipped_scores = list(zip(*scores))
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     512             estimator.fit(X_train, **fit_params)
#     513         else:
# --> 514             estimator.fit(X_train, y_train, **fit_params)
#     515
#     516     except Exception as e:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     328                     t, self, X, y, sample_weight, i, len(trees),
#     329                     verbose=self.verbose, class_weight=self.class_weight)
# --> 330                 for i, t in enumerate(trees))
#     331
#     332             # Collect newly grown trees
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     116             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     117
# --> 118         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     119     else:
#     120         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1155             sample_weight=sample_weight,
#    1156             check_input=check_input,
# -> 1157             X_idx_sorted=X_idx_sorted)
#    1158         return self
#    1159
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     378                                            min_impurity_split)
#     379
# --> 380         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     381
#     382         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
rfreg.fit(X,Y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
np.exp(rfreg.predict(predicao))
# Out:
# array([13008.56396079,  5043.3051758 ,  2338.51388946, ...,
#         1381.17278144,  2109.83356699,   824.59356755])

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV , KFold , cross_val_score
from sklearn.metrics import mean_squared_log_error,mean_squared_error, r2_score,mean_absolute_error 

X_train, X_test, y_train, y_test = train_test_split(X,Y)

# %%
clf_rf = RandomForestRegressor()
clf_rf.fit(X_train , y_train)
accuracies = cross_val_score(estimator = clf_rf, X = X_train, y = y_train, cv = 5,verbose = 1)
y_pred = clf_rf.predict(X_test)
print('')
print('###### Random Forest ######')
print('Score : %.4f' % clf_rf.score(X_test, y_test))
print(accuracies)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)**0.5
r2 = r2_score(y_test, y_pred)

print('')
print('MSE    : %0.2f ' % mse)
print('MAE    : %0.2f ' % mae)
print('RMSE   : %0.2f ' % rmse)
print('R2     : %0.2f ' % r2)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ###### Random Forest ######
# Score : 0.9905
# [0.98958596 0.99096261 0.9894792  0.9902075  0.98949312]
#
# MSE    : 0.01
# MAE    : 0.07
# RMSE   : 0.10
# R2     : 0.99
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    5.0s finished

# %%
no_of_test=[150]

params_dict={'n_estimators':no_of_test,'n_jobs':[-1],'max_features':["auto",'sqrt','log2']}
clf_rf=GridSearchCV(estimator=RandomForestRegressor(),param_grid=params_dict)

# %%
clf_rf.fit(X_train,y_train)
print('Score : %.4f' % clf_rf.score(X_test, y_test))
pred=clf_rf.predict(X_test)
r2 = r2_score(y_test, pred)
print('R2     : %0.2f ' % r2)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:714: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# Score : 0.9914
# R2     : 0.99

# %%
clf_rf.best_params_
# Out:
# {'max_features': 'auto', 'n_estimators': 150, 'n_jobs': -1}

# %%
clf_rf
# Out:
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                              max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators='warn', n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [150], 'n_jobs': [-1]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
clf_rf.fit(X,Y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:714: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                              max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators='warn', n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [150], 'n_jobs': [-1]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
from sklearn.tree import export_graphviz
import graphviz

features = Data_set.columns

dot_data = export_graphviz(model, feature_names = features, filled=True, rounded=True)#filled e rounded sao so frescura pra ficar bonito
grafico = graphviz.Source(dot_data)
grafico

# %%
sample_sub.head()
# Out:
#    id     price
# 0   0  12345.67
# 1   1  12345.67
# 2   2  12345.67
# 3   3  12345.67
# 4   4  12345.67

# %%
sample_sub['price'] =np.exp(clf_rf.predict(predicao))
sample_sub.head()
# Out:
#    id         price
# 0   0  13034.774503
# 1   1   5188.788703
# 2   2   2323.315024
# 3   3   4614.977474
# 4   4   2320.569740

# %%
sample_sub = sample_sub.drop(columns='id')

# %%
sample_sub.to_csv('DatasetLimpoNJobs150RandomSeed301.csv')

# %%
X = Data_set.drop(columns=['log_price'])

# %%
Y = Data_set['log_price']

# %%
rfr = RandomForestRegressor(random_state=SEED)

# %%
# Out:
# mtrand.RandomState

# %%
teste_modelo(rfr, X,Y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Resultados para o modelo : RandomForestRegressor - 0.9904646563692447

# %%
rfr.fit(X,Y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=301, verbose=0,
#                       warm_start=False)

# %%
np.exp(rfr.predict(predicao))
# Out:
# array([13352.19835605,  5314.76194481,  2355.94381021, ...,
#         1300.75363372,  2167.39156216,   782.55824093])

# %%
sample_sub['price'] = np.exp(rfr.predict(predicao))
sample_sub.head()
# Out:
#           price
# 0  13352.198356
# 1   5314.761945
# 2   2355.943810
# 3   5026.297543
# 4   2287.673553

# %%
sample_sub = sample_sub.drop(columns='id')
sample_sub.head()
# Out:
#           price
# 0  12429.533651
# 1   5112.802231
# 2   2415.265568
# 3   4969.915136
# 4   2218.346142

# %%
sample_sub.to_csv('treino5.csv')
